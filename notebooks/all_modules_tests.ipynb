# %% [markdown]
# # 四大模块统一测试（A/B/C/D）
#
# 说明：本 notebook 按模块分成 4 个运行 block（A/B/C/D），每个 block 单独输出该模块的测试结果（通过/跳过/失败列表）。
#
# 默认使用 `../build` 目录；如需重新编译，把 `BUILD_FIRST = True`，先运行第一个 code cell。

# %%
from __future__ import annotations

import os
import subprocess
from pathlib import Path

ROOT = (Path("..") if Path.cwd().name == "notebooks" else Path(".")).resolve()
BUILD_DIR = (ROOT / "build").resolve()

# 基本参数
TIMEOUT_S = 30
BUILD_FIRST = False

# 每个模块内部：失败后是否继续跑完该模块
CONTINUE_ON_FAIL = False

# 模块用例分组
TESTS_A = [
    "test_eventloop",
    "test_select_poller",
    "test_tcpserver",
    "test_tcpclient",
    "test_connector_retry",
    "test_idle_cleanup",
    "test_udp_proxy",
    "test_l4_tunnel",
    "test_conn_limit",
    "test_conn_limit_user_service",
    "test_allocator",
    "test_buddy_allocator",
    "test_memory_stats",
    "test_hugepage_slab",
    "test_multithread",
]

TESTS_B = [
    "test_balancer",
    "test_leastconn",
    "test_leastqueue",
    "test_rtw",
    "test_gpu_balancer",
    "test_balancer_health",
    "test_http_health_checker",
    "test_ai_service_check",
    "test_script_health_checker",
    "test_warmup",
    "test_backend_manager",
    "test_backend_conn_pool",
    "test_model_affinity",
    "test_service_discovery",
    "test_dynamic_register",
    "test_passive_failover",
]

TESTS_C = [
    "test_http",
    "test_httpserver",
    "test_http_keepalive_chunked",
    "test_http2_basic",
    "test_grpc_h2c",
    "test_websocket_upgrade",
    "test_protocol_conversion",
    "test_compression_conversion",
    "test_rewrite_rules",
    "test_traffic_mirror",
    "test_api_aggregate",
    "test_cache_memcached",
    "test_cache_redis",
    "test_http_batching",
    "test_batch_split",
    "test_streaming_response",
    "test_cookie",
    "test_model_version_routing",
]

TESTS_D = [
    "test_stats_json",
    "test_stats_backends",
    "test_history",
    "test_dashboard",
    "test_diagnostics",
    "test_config_as_code",
    "test_config_web",
    "test_alert_webhook",
    "test_alert_channels",
    "test_alert_anomaly",
    "test_token_bucket",
    "test_per_ip_rate_limit",
    "test_per_path_rate_limit",
    "test_access_control",
    "test_audit_logger",
    "test_ddos_accept_limit",
    "test_congestion_control",
    "test_priority_queue",
    "test_fair_queue",
    "test_edf",
    "test_tls_acme",
    "test_plugin_manager",
    "test_plugin_http",
]

TEST_GROUPS: dict[str, list[str]] = {"A": TESTS_A, "B": TESTS_B, "C": TESTS_C, "D": TESTS_D}
results: dict[str, dict] = {}


def sh(cmd: list[str], *, cwd: Path = ROOT, timeout: int | None = None) -> None:
    print("$", " ".join(cmd))
    subprocess.run(cmd, cwd=str(cwd), check=True, timeout=timeout)


def maybe_build() -> None:
    BUILD_DIR.mkdir(parents=True, exist_ok=True)
    cache = BUILD_DIR / "CMakeCache.txt"
    if not cache.exists():
        sh(["cmake", "-S", str(ROOT), "-B", str(BUILD_DIR)])
    jobs = str(max(1, os.cpu_count() or 4))
    sh(["cmake", "--build", str(BUILD_DIR), "-j", jobs])


def _format_rc(rc: int) -> str:
    if rc < 0:
        return f"signal={-rc}"
    return f"exit={rc}"


def run_module(m: str) -> dict:
    tests = TEST_GROUPS.get(m, [])
    ran: list[str] = []
    skipped: list[str] = []
    failures: list[tuple[str, str]] = []

    print("\n" + "=" * 60)
    print(f"MODULE {m}")
    print("=" * 60)

    for t in tests:
        p = BUILD_DIR / t
        if not p.exists():
            print(f"SKIP {t} (missing: {p})")
            skipped.append(t)
            continue

        print(f"RUN {t}")
        try:
            sh([str(p)], cwd=ROOT, timeout=TIMEOUT_S)
            ran.append(t)
        except subprocess.TimeoutExpired:
            print(f"FAIL {t} timeout={TIMEOUT_S}s")
            failures.append((t, f"timeout={TIMEOUT_S}s"))
            if not CONTINUE_ON_FAIL:
                break
        except subprocess.CalledProcessError as e:
            print(f"FAIL {t} {_format_rc(e.returncode)}")
            failures.append((t, _format_rc(e.returncode)))
            if not CONTINUE_ON_FAIL:
                break

    summary = {
        "module": m,
        "ran": ran,
        "skipped": skipped,
        "failures": failures,
        "ok": len(failures) == 0,
    }

    print("\n--- SUMMARY ---")
    print("OK" if summary["ok"] else "FAIL")
    print("ran:", len(ran), "skipped:", len(skipped), "failed:", len(failures))
    if failures:
        print("failed list:", ", ".join([f"{n}({r})" for n, r in failures]))
    return summary


if BUILD_FIRST:
    maybe_build()

# %%
# Block A
results["A"] = run_module("A")
# Out:
# ============================================================
# MODULE A
# ============================================================
# RUN test_eventloop
# $ /home/huazi/Workspace/Projects/linux大作业/build/test_eventloop
# [2026-01-14 19:19:41.383] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/unit/test_eventloop.cpp:41] Starting EventLoop test
# [2026-01-14 19:19:41.383] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EpollPoller.cpp:147] Using EpollPoller
# [2026-01-14 19:19:41.383] [DEBUG] [/home/huazi/Workspace/Projects/linux大作业/src/network/EventLoop.cpp:39] EventLoop created 0x7fff1db86f70 in thread 140018339403648
# [2026-01-14 19:19:41.383] [DEBUG] [/home/huazi/Workspace/Projects/linux大作业/src/network/EpollPoller.cpp:68] fd = 4 events = 3 index = -1
# [2026-01-14 19:19:41.383] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EventLoop.cpp:61] EventLoop 0x7fff1db86f70 start looping
# [2026-01-14 19:19:42.384] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/unit/test_eventloop.cpp:48] Quitting main loop from thread
# [2026-01-14 19:19:42.384] [DEBUG] [/home/huazi/Workspace/Projects/linux大作业/src/network/EventLoop.cpp:108] EventLoop::WakeUp() wrote to fd 4
# [2026-01-14 19:19:42.384] [DEBUG] [/home/huazi/Workspace/Projects/linux大作业/src/network/EpollPoller.cpp:42] 1 events happened
# [2026-01-14 19:19:42.384] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EventLoop.cpp:72] EventLoop 0x7fff1db86f70 stop looping
# [2026-01-14 19:19:42.384] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/unit/test_eventloop.cpp:55] Main loop test passed
# [2026-01-14 19:19:42.384] [DEBUG] [/home/huazi/Workspace/Projects/linux大作业/src/network/EpollPoller.cpp:68] fd = 4 events = 0 index = 1
# [2026-01-14 19:19:42.384] [DEBUG] [/home/huazi/Workspace/Projects/linux大作业/src/network/EpollPoller.cpp:98] RemoveChannel fd = 4
# RUN test_select_poller
# $ /home/huazi/Workspace/Projects/linux大作业/build/test_select_poller
# [2026-01-14 19:19:42.421] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EpollPoller.cpp:141] Using SelectPoller
# RUN test_tcpserver
# $ /home/huazi/Workspace/Projects/linux大作业/build/test_tcpserver
# [2026-01-14 19:19:42.448] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/integration/test_tcpserver.cpp:90] Starting EchoServer test
# [2026-01-14 19:19:42.448] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EpollPoller.cpp:147] Using EpollPoller
# [2026-01-14 19:19:42.448] [DEBUG] [/home/huazi/Workspace/Projects/linux大作业/src/network/EventLoop.cpp:39] EventLoop created 0x7ffc27737500 in thread 140192014464896
# [2026-01-14 19:19:42.448] [DEBUG] [/home/huazi/Workspace/Projects/linux大作业/src/network/EpollPoller.cpp:68] fd = 4 events = 3 index = -1
# [2026-01-14 19:19:42.448] [DEBUG] [/home/huazi/Workspace/Projects/linux大作业/src/network/EpollPoller.cpp:68] fd = 5 events = 3 index = -1
# [2026-01-14 19:19:42.449] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EventLoop.cpp:61] EventLoop 0x7ffc27737500 start looping
# [2026-01-14 19:19:42.649] [DEBUG] [/home/huazi/Workspace/Projects/linux大作业/src/network/EpollPoller.cpp:42] 1 events happened
# [2026-01-14 19:19:42.649] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/TcpServer.cpp:195] TcpServer::NewConnection [EchoServer] - new connection [EchoServer-0.0.0.0:9981#1] from 127.0.0.1:54500
# [2026-01-14 19:19:42.649] [DEBUG] [/home/huazi/Workspace/Projects/linux大作业/src/common/SlabAllocator.cpp:132] SlabAllocator allocated new chunk, total slots: 1024
# [2026-01-14 19:19:42.650] [DEBUG] [/home/huazi/Workspace/Projects/linux大作业/src/common/SlabAllocator.cpp:132] SlabAllocator allocated new chunk, total slots: 512
# [2026-01-14 19:19:42.650] [DEBUG] [/home/huazi/Workspace/Projects/linux大作业/src/common/SlabAllocator.cpp:132] SlabAllocator allocated new chunk, total slots: 256
# [2026-01-14 19:19:42.650] [DEBUG] [/home/huazi/Workspace/Projects/linux大作业/src/common/SlabAllocator.cpp:132] SlabAllocator allocated new chunk, total slots: 128
# [2026-01-14 19:19:42.650] [DEBUG] [/home/huazi/Workspace/Projects/linux大作业/src/common/SlabAllocator.cpp:132] SlabAllocator allocated new chunk, total slots: 64
# [2026-01-14 19:19:42.650] [DEBUG] [/home/huazi/Workspace/Projects/linux大作业/src/common/SlabAllocator.cpp:132] SlabAllocator allocated new chunk, total slots: 32
# [2026-01-14 19:19:42.650] [DEBUG] [/home/huazi/Workspace/Projects/linux大作业/src/common/SlabAllocator.cpp:132] SlabAllocator allocated new chunk, total slots: 16
# [2026-01-14 19:19:42.650] [DEBUG] [/home/huazi/Workspace/Projects/linux大作业/src/common/SlabAllocator.cpp:132] SlabAllocator allocated new chunk, total slots: 8
# [2026-01-14 19:19:42.650] [DEBUG] [/home/huazi/Workspace/Projects/linux大作业/src/common/SlabAllocator.cpp:132] SlabAllocator allocated new chunk, total slots: 4
# [2026-01-14 19:19:42.650] [DEBUG] [/home/huazi/Workspace/Projects/linux大作业/src/common/SlabAllocator.cpp:132] SlabAllocator allocated new chunk, total slots: 2
# [2026-01-14 19:19:42.650] [DEBUG] [/home/huazi/Workspace/Projects/linux大作业/src/common/SlabAllocator.cpp:132] SlabAllocator allocated new chunk, total slots: 1
# [2026-01-14 19:19:42.650] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/common/MemoryPool.cpp:53] MemoryPool buddy enabled: min_kb=128 arena_kb=8192 keep_arenas=1 max_arenas=8
# [2026-01-14 19:19:42.650] [DEBUG] [/home/huazi/Workspace/Projects/linux大作业/src/network/TcpConnection.cpp:52] TcpConnection::ctor[EchoServer-0.0.0.0:9981#1] at 0x5562217410f0 fd=7
# [2026-01-14 19:19:42.650] [DEBUG] [/home/huazi/Workspace/Projects/linux大作业/src/network/EpollPoller.cpp:68] fd = 7 events = 3 index = -1
# [2026-01-14 19:19:42.651] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/integration/test_tcpserver.cpp:64] EchoServer - 127.0.0.1:54500 -> 0.0.0.0:0 is UP
# [2026-01-14 19:19:42.651] [DEBUG] [/home/huazi/Workspace/Projects/linux大作业/src/network/EpollPoller.cpp:42] 1 events happened
# [2026-01-14 19:19:42.651] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/integration/test_tcpserver.cpp:71] EchoServer-0.0.0.0:9981#1 echo 6 bytes, data received at 1768389582
# [2026-01-14 19:19:42.651] [DEBUG] [/home/huazi/Workspace/Projects/linux大作业/src/network/EpollPoller.cpp:42] 1 events happened
# [2026-01-14 19:19:42.651] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/integration/test_tcpserver.cpp:71] EchoServer-0.0.0.0:9981#1 echo 5 bytes, data received at 1768389582
# [2026-01-14 19:19:42.651] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/integration/test_tcpserver.cpp:79] Quit command received. Stopping server...
# [2026-01-14 19:19:42.651] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EventLoop.cpp:72] EventLoop 0x7ffc27737500 stop looping
# [2026-01-14 19:19:42.651] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/integration/test_tcpserver.cpp:119] EchoServer test finished
# [2026-01-14 19:19:42.651] [DEBUG] [/home/huazi/Workspace/Projects/linux大作业/src/network/TcpConnection.cpp:58] TcpConnection::dtor[EchoServer-0.0.0.0:9981#1] at 0x5562217410f0 fd=7 state=2
# [2026-01-14 19:19:42.651] [DEBUG] [/home/huazi/Workspace/Projects/linux大作业/src/network/EpollPoller.cpp:68] fd = 5 events = 0 index = 1
# [2026-01-14 19:19:42.651] [DEBUG] [/home/huazi/Workspace/Projects/linux大作业/src/network/EpollPoller.cpp:98] RemoveChannel fd = 5
# [2026-01-14 19:19:42.651] [DEBUG] [/home/huazi/Workspace/Projects/linux大作业/src/network/EpollPoller.cpp:68] fd = 4 events = 0 index = 1
# [2026-01-14 19:19:42.651] [DEBUG] [/home/huazi/Workspace/Projects/linux大作业/src/network/EpollPoller.cpp:98] RemoveChannel fd = 4
# RUN test_tcpclient
# $ /home/huazi/Workspace/Projects/linux大作业/build/test_tcpclient
# [2026-01-14 19:19:42.673] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EpollPoller.cpp:147] Using EpollPoller
# [2026-01-14 19:19:42.673] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EventLoop.cpp:61] EventLoop 0x7f4e94dfec10 start looping
# [2026-01-14 19:19:42.693] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EpollPoller.cpp:147] Using EpollPoller
# [2026-01-14 19:19:42.693] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/TcpClient.cpp:26] TcpClient::TcpClient[TestClient] - connector 0x55b64d90bbc0
# [2026-01-14 19:19:42.693] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/TcpClient.cpp:52] TcpClient::Connect[TestClient] - connecting to 127.0.0.1:33259
# [2026-01-14 19:19:42.693] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EventLoop.cpp:61] EventLoop 0x7ffcfe7f9920 start looping
# [2026-01-14 19:19:42.693] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/TcpServer.cpp:195] TcpServer::NewConnection [TestServer] - new connection [TestServer-0.0.0.0:33259#1] from 127.0.0.1:46846
# [2026-01-14 19:19:42.693] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/common/MemoryPool.cpp:53] MemoryPool buddy enabled: min_kb=128 arena_kb=8192 keep_arenas=1 max_arenas=8
# [2026-01-14 19:19:42.693] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/integration/test_tcpclient.cpp:80] Client: Connected to 127.0.0.1:33259
# [2026-01-14 19:19:42.693] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/integration/test_tcpclient.cpp:50] Server: New connection from 127.0.0.1:46846
# [2026-01-14 19:19:42.694] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/integration/test_tcpclient.cpp:55] Server received: Hello Proxy
# [2026-01-14 19:19:42.694] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/integration/test_tcpclient.cpp:70] Client received: Hello Proxy
# [2026-01-14 19:19:42.694] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/integration/test_tcpclient.cpp:72] Test PASS
# [2026-01-14 19:19:42.694] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EventLoop.cpp:72] EventLoop 0x7ffcfe7f9920 stop looping
# [2026-01-14 19:19:42.694] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/TcpServer.cpp:223] TcpServer::RemoveConnectionInLoop [TestServer] - connection TestServer-0.0.0.0:33259#1
# [2026-01-14 19:19:42.694] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EventLoop.cpp:72] EventLoop 0x7f4e94dfec10 stop looping
# [2026-01-14 19:19:42.694] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/TcpClient.cpp:30] TcpClient::~TcpClient[TestClient] - connector 0x55b64d90bbc0
# RUN test_connector_retry
# $ /home/huazi/Workspace/Projects/linux大作业/build/test_connector_retry
# [2026-01-14 19:19:42.705] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EpollPoller.cpp:147] Using EpollPoller
# [2026-01-14 19:19:42.706] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EventLoop.cpp:61] EventLoop 0x7ffc7bfcc180 start looping
# [2026-01-14 19:19:42.706] [ERROR] [/home/huazi/Workspace/Projects/linux大作业/src/network/Connector.cpp:179] Connector::HandleError
# [2026-01-14 19:19:42.706] [WARN ] [/home/huazi/Workspace/Projects/linux大作业/src/network/Connector.cpp:185] SO_ERROR = 111 Connection refused
# [2026-01-14 19:19:42.706] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/Connector.cpp:194] Connector::Retry - Retry connecting to 127.0.0.1:9984 in 500 milliseconds.
# [2026-01-14 19:19:43.206] [ERROR] [/home/huazi/Workspace/Projects/linux大作业/src/network/Connector.cpp:179] Connector::HandleError
# [2026-01-14 19:19:43.206] [WARN ] [/home/huazi/Workspace/Projects/linux大作业/src/network/Connector.cpp:185] SO_ERROR = 111 Connection refused
# [2026-01-14 19:19:43.206] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/Connector.cpp:194] Connector::Retry - Retry connecting to 127.0.0.1:9984 in 1000 milliseconds.
# [2026-01-14 19:19:44.206] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EventLoop.cpp:72] EventLoop 0x7ffc7bfcc180 stop looping
# RUN test_idle_cleanup
# $ /home/huazi/Workspace/Projects/linux大作业/build/test_idle_cleanup
# [2026-01-14 19:19:44.235] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EpollPoller.cpp:147] Using EpollPoller
# [2026-01-14 19:19:44.235] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EventLoop.cpp:61] EventLoop 0x7fffd2790140 start looping
# [2026-01-14 19:19:44.336] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/TcpServer.cpp:195] TcpServer::NewConnection [IdleCleanupServer] - new connection [IdleCleanupServer-0.0.0.0:9983#1] from 127.0.0.1:48676
# [2026-01-14 19:19:44.336] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/common/MemoryPool.cpp:53] MemoryPool buddy enabled: min_kb=128 arena_kb=8192 keep_arenas=1 max_arenas=8
# [2026-01-14 19:19:44.635] [WARN ] [/home/huazi/Workspace/Projects/linux大作业/src/network/TcpServer.cpp:148] TcpServer::CleanupIdleConnections [IdleCleanupServer] closing idle conn IdleCleanupServer-0.0.0.0:9983#1 peer=127.0.0.1:48676
# [2026-01-14 19:19:44.635] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/TcpServer.cpp:223] TcpServer::RemoveConnectionInLoop [IdleCleanupServer] - connection IdleCleanupServer-0.0.0.0:9983#1
# [2026-01-14 19:19:44.786] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EventLoop.cpp:72] EventLoop 0x7fffd2790140 stop looping
# RUN test_udp_proxy
# $ /home/huazi/Workspace/Projects/linux大作业/build/test_udp_proxy
# [2026-01-14 19:19:44.817] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EpollPoller.cpp:147] Using EpollPoller
# [2026-01-14 19:19:44.817] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/UdpProxyServer.cpp:85] TestUdpProxy starts listening (UDP fd=6)
# [2026-01-14 19:19:44.817] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EventLoop.cpp:61] EventLoop 0x7ffe86a78ee0 start looping
# [2026-01-14 19:19:44.923] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EventLoop.cpp:72] EventLoop 0x7ffe86a78ee0 stop looping
# RUN test_l4_tunnel
# $ /home/huazi/Workspace/Projects/linux大作业/build/test_l4_tunnel
# RUN test_conn_limit
# $ /home/huazi/Workspace/Projects/linux大作业/build/test_conn_limit
# [2026-01-14 19:19:45.213] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EpollPoller.cpp:147] Using EpollPoller
# [2026-01-14 19:19:45.214] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EventLoop.cpp:61] EventLoop 0x7ffe23b974f0 start looping
# [2026-01-14 19:19:45.414] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/TcpServer.cpp:195] TcpServer::NewConnection [ConnLimitServer] - new connection [ConnLimitServer-0.0.0.0:9982#1] from 127.0.0.1:44366
# [2026-01-14 19:19:45.415] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/common/MemoryPool.cpp:53] MemoryPool buddy enabled: min_kb=128 arena_kb=8192 keep_arenas=1 max_arenas=8
# [2026-01-14 19:19:45.415] [WARN ] [/home/huazi/Workspace/Projects/linux大作业/src/network/TcpServer.cpp:175] TcpServer::NewConnection [ConnLimitServer] reject (max total reached): 127.0.0.1:44368 total=1 limit=1
# [2026-01-14 19:19:45.415] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EventLoop.cpp:72] EventLoop 0x7ffe23b974f0 stop looping
# RUN test_conn_limit_user_service
# $ /home/huazi/Workspace/Projects/linux大作业/build/test_conn_limit_user_service
# [2026-01-14 19:19:45.440] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EpollPoller.cpp:147] Using EpollPoller
# [2026-01-14 19:19:45.440] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/ProxyServer.cpp:2765] Added backend: 127.0.0.1:9100 weight=1
# [2026-01-14 19:19:45.441] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/ProxyServer.cpp:2750] ProxyServer starts listening on 0.0.0.0:9981
# [2026-01-14 19:19:45.441] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EventLoop.cpp:61] EventLoop 0x7ffcdadedc90 start looping
# [2026-01-14 19:19:45.641] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/TcpServer.cpp:195] TcpServer::NewConnection [ProxyConnLimitUserService] - new connection [ProxyConnLimitUserService-0.0.0.0:9981#1] from 127.0.0.1:54502
# [2026-01-14 19:19:45.642] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/common/MemoryPool.cpp:53] MemoryPool buddy enabled: min_kb=128 arena_kb=8192 keep_arenas=1 max_arenas=8
# [2026-01-14 19:19:45.642] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/ProxyServer.cpp:2782] New connection from 127.0.0.1:54502
# [2026-01-14 19:19:45.642] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/TcpServer.cpp:195] TcpServer::NewConnection [ProxyConnLimitUserService] - new connection [ProxyConnLimitUserService-0.0.0.0:9981#2] from 127.0.0.1:54504
# [2026-01-14 19:19:45.642] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/ProxyServer.cpp:2782] New connection from 127.0.0.1:54504
# [2026-01-14 19:19:45.642] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/ProxyServer.cpp:4344] HTTP Request: GET /svc/one
# [2026-01-14 19:19:45.642] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/TcpClient.cpp:26] TcpClient::TcpClient[PoolBackend] - connector 0x555b26f87a20
# [2026-01-14 19:19:45.642] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/TcpClient.cpp:52] TcpClient::Connect[PoolBackend] - connecting to 127.0.0.1:9100
# [2026-01-14 19:19:45.642] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/ProxyServer.cpp:2791] Connection closed: ProxyConnLimitUserService-0.0.0.0:9981#2
# [2026-01-14 19:19:45.642] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/TcpServer.cpp:223] TcpServer::RemoveConnectionInLoop [ProxyConnLimitUserService] - connection ProxyConnLimitUserService-0.0.0.0:9981#2
# [2026-01-14 19:19:45.642] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/TcpServer.cpp:195] TcpServer::NewConnection [ProxyConnLimitUserService] - new connection [ProxyConnLimitUserService-0.0.0.0:9981#3] from 127.0.0.1:54518
# [2026-01-14 19:19:45.642] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/ProxyServer.cpp:2782] New connection from 127.0.0.1:54518
# [2026-01-14 19:19:45.643] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EventLoop.cpp:72] EventLoop 0x7ffcdadedc90 stop looping
# RUN test_allocator
# $ /home/huazi/Workspace/Projects/linux大作业/build/test_allocator
# [2026-01-14 19:19:45.662] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/unit/test_allocator.cpp:10] Starting SlabAllocator test
# [2026-01-14 19:19:45.663] [DEBUG] [/home/huazi/Workspace/Projects/linux大作业/src/common/SlabAllocator.cpp:132] SlabAllocator allocated new chunk, total slots: 512
# [2026-01-14 19:19:45.663] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/unit/test_allocator.cpp:15] Block size: 128
# [2026-01-14 19:19:45.663] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/unit/test_allocator.cpp:32] Allocated 100 blocks
# [2026-01-14 19:19:45.663] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/unit/test_allocator.cpp:40] Deallocated all blocks
# [2026-01-14 19:19:45.663] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/unit/test_allocator.cpp:45] Re-allocation successful
# [2026-01-14 19:19:45.663] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/unit/test_allocator.cpp:49] SlabAllocator test passed
# RUN test_buddy_allocator
# $ /home/huazi/Workspace/Projects/linux大作业/build/test_buddy_allocator
# RUN test_memory_stats
# $ /home/huazi/Workspace/Projects/linux大作业/build/test_memory_stats
# [2026-01-14 19:19:45.681] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/common/MemoryPool.cpp:53] MemoryPool buddy enabled: min_kb=128 arena_kb=8192 keep_arenas=1 max_arenas=8
# [2026-01-14 19:19:45.681] [WARN ] [/home/huazi/Workspace/Projects/linux大作业/src/common/MemoryPool.cpp:70] MemoryPool: Large allocation 16777216 bytes, using malloc directly
# RUN test_hugepage_slab
# $ /home/huazi/Workspace/Projects/linux大作业/build/test_hugepage_slab
# RUN test_multithread
# $ /home/huazi/Workspace/Projects/linux大作业/build/test_multithread
# [2026-01-14 19:19:45.707] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/integration/test_multithread.cpp:62] Main thread ID: 140277476247424
# [2026-01-14 19:19:45.707] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EpollPoller.cpp:147] Using EpollPoller
# [2026-01-14 19:19:45.707] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/protocol/HttpServer.cpp:22] HttpServer[MT-HttpServer] starts listening on 0.0.0.0:8001
# [2026-01-14 19:19:45.707] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EpollPoller.cpp:147] Using EpollPoller
# [2026-01-14 19:19:45.707] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EventLoop.cpp:61] EventLoop 0x7f94e43feda0 start looping
# [2026-01-14 19:19:45.707] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EpollPoller.cpp:147] Using EpollPoller
# [2026-01-14 19:19:45.707] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EventLoop.cpp:61] EventLoop 0x7f94e3bfdda0 start looping
# [2026-01-14 19:19:45.708] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EpollPoller.cpp:147] Using EpollPoller
# [2026-01-14 19:19:45.708] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EventLoop.cpp:61] EventLoop 0x7f94e33fcda0 start looping
# [2026-01-14 19:19:45.708] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EventLoop.cpp:61] EventLoop 0x7fff2f502810 start looping
# [2026-01-14 19:19:45.908] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/TcpServer.cpp:195] TcpServer::NewConnection [MT-HttpServer] - new connection [MT-HttpServer-0.0.0.0:8001#1] from 127.0.0.1:49706
# [2026-01-14 19:19:45.909] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/common/MemoryPool.cpp:53] MemoryPool buddy enabled: min_kb=128 arena_kb=8192 keep_arenas=1 max_arenas=8
# [2026-01-14 19:19:45.909] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/integration/test_multithread.cpp:78] Request on thread 140277461284544, path: /hello
# [2026-01-14 19:19:45.909] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/TcpServer.cpp:223] TcpServer::RemoveConnectionInLoop [MT-HttpServer] - connection MT-HttpServer-0.0.0.0:8001#1
# [2026-01-14 19:19:45.910] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/TcpServer.cpp:195] TcpServer::NewConnection [MT-HttpServer] - new connection [MT-HttpServer-0.0.0.0:8001#2] from 127.0.0.1:49716
# [2026-01-14 19:19:45.910] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/integration/test_multithread.cpp:78] Request on thread 140277452891840, path: /hello
# [2026-01-14 19:19:45.910] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/TcpServer.cpp:223] TcpServer::RemoveConnectionInLoop [MT-HttpServer] - connection MT-HttpServer-0.0.0.0:8001#2
# [2026-01-14 19:19:45.910] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/TcpServer.cpp:195] TcpServer::NewConnection [MT-HttpServer] - new connection [MT-HttpServer-0.0.0.0:8001#3] from 127.0.0.1:49726
# [2026-01-14 19:19:45.914] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/integration/test_multithread.cpp:78] Request on thread 140277444499136, path: /hello
# [2026-01-14 19:19:45.918] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/TcpServer.cpp:195] TcpServer::NewConnection [MT-HttpServer] - new connection [MT-HttpServer-0.0.0.0:8001#4] from 127.0.0.1:49734
# [2026-01-14 19:19:45.918] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/TcpServer.cpp:223] TcpServer::RemoveConnectionInLoop [MT-HttpServer] - connection MT-HttpServer-0.0.0.0:8001#3
# [2026-01-14 19:19:45.918] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/integration/test_multithread.cpp:78] Request on thread 140277461284544, path: /hello
# [2026-01-14 19:19:45.920] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/TcpServer.cpp:195] TcpServer::NewConnection [MT-HttpServer] - new connection [MT-HttpServer-0.0.0.0:8001#5] from 127.0.0.1:49742
# [2026-01-14 19:19:45.920] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/integration/test_multithread.cpp:78] Request on thread 140277452891840, path: /hello
# [2026-01-14 19:19:45.920] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/TcpServer.cpp:223] TcpServer::RemoveConnectionInLoop [MT-HttpServer] - connection MT-HttpServer-0.0.0.0:8001#4
# [2026-01-14 19:19:45.921] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/TcpServer.cpp:195] TcpServer::NewConnection [MT-HttpServer] - new connection [MT-HttpServer-0.0.0.0:8001#6] from 127.0.0.1:49752
# [2026-01-14 19:19:45.921] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/TcpServer.cpp:223] TcpServer::RemoveConnectionInLoop [MT-HttpServer] - connection MT-HttpServer-0.0.0.0:8001#5
# [2026-01-14 19:19:45.921] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/integration/test_multithread.cpp:78] Request on thread 140277444499136, path: /hello
# [2026-01-14 19:19:45.921] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EventLoop.cpp:72] EventLoop 0x7fff2f502810 stop looping
# [2026-01-14 19:19:45.922] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EventLoop.cpp:72] EventLoop 0x7f94e43feda0 stop looping
# [2026-01-14 19:19:45.922] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EventLoop.cpp:72] EventLoop 0x7f94e3bfdda0 stop looping
# [2026-01-14 19:19:45.922] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EventLoop.cpp:72] EventLoop 0x7f94e33fcda0 stop looping
#
# --- SUMMARY ---
# OK
# ran: 15 skipped: 0 failed: 0

# %%
# Block B
results["B"] = run_module("B")
# Out:
# ============================================================
# MODULE B
# ============================================================
# RUN test_balancer
# $ /home/huazi/Workspace/Projects/linux大作业/build/test_balancer
# [2026-01-14 19:19:59.216] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/unit/test_balancer.cpp:11] Starting ConsistentHashBalancer test
# [2026-01-14 19:19:59.219] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/unit/test_balancer.cpp:28] Distribution Results (10000 requests):
# [2026-01-14 19:19:59.219] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/unit/test_balancer.cpp:30]   ServerA: 5317 (53.17%)
# [2026-01-14 19:19:59.219] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/unit/test_balancer.cpp:30]   ServerB: 1443 (14.43%)
# [2026-01-14 19:19:59.219] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/unit/test_balancer.cpp:30]   ServerC: 3240 (32.4%)
# [2026-01-14 19:19:59.219] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/unit/test_balancer.cpp:38] Consistency check: PASS
# [2026-01-14 19:19:59.219] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/unit/test_balancer.cpp:44] Removing ServerB...
# [2026-01-14 19:19:59.220] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/unit/test_balancer.cpp:47] New mapping for 10.0.0.1: ServerA
# [2026-01-14 19:19:59.220] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/unit/test_balancer.cpp:49] ConsistentHashBalancer test passed
# RUN test_leastconn
# $ /home/huazi/Workspace/Projects/linux大作业/build/test_leastconn
# RUN test_leastqueue
# $ /home/huazi/Workspace/Projects/linux大作业/build/test_leastqueue
# RUN test_rtw
# $ /home/huazi/Workspace/Projects/linux大作业/build/test_rtw
# RUN test_gpu_balancer
# $ /home/huazi/Workspace/Projects/linux大作业/build/test_gpu_balancer
# RUN test_balancer_health
# $ /home/huazi/Workspace/Projects/linux大作业/build/test_balancer_health
# [2026-01-14 19:19:59.278] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/unit/test_balancer_health.cpp:16] === Testing RoundRobinBalancer ===
# [2026-01-14 19:19:59.278] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/unit/test_balancer_health.cpp:30] RoundRobin basic: PASS
# [2026-01-14 19:19:59.278] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/unit/test_balancer_health.cpp:49] Weighted RoundRobin: PASS
# [2026-01-14 19:19:59.278] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/unit/test_balancer_health.cpp:60] === Testing TcpHealthChecker ===
# [2026-01-14 19:19:59.278] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EpollPoller.cpp:147] Using EpollPoller
# [2026-01-14 19:19:59.279] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EventLoop.cpp:61] EventLoop 0x7ffc8998ad30 start looping
# [2026-01-14 19:19:59.279] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/unit/test_balancer_health.cpp:78] Check 127.0.0.1:9999: Healthy (EXPECTED)
# [2026-01-14 19:19:59.279] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/unit/test_balancer_health.cpp:88] Check 127.0.0.1:9998: Unhealthy (EXPECTED)
# [2026-01-14 19:19:59.279] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EventLoop.cpp:72] EventLoop 0x7ffc8998ad30 stop looping
# RUN test_http_health_checker
# $ /home/huazi/Workspace/Projects/linux大作业/build/test_http_health_checker
# [2026-01-14 19:19:59.286] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EpollPoller.cpp:147] Using EpollPoller
# [2026-01-14 19:19:59.286] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EventLoop.cpp:61] EventLoop 0x7fffdbe63d50 start looping
# [2026-01-14 19:19:59.287] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/unit/test_http_health_checker.cpp:63] Check 127.0.0.1:9997 healthy=1
# [2026-01-14 19:19:59.287] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/unit/test_http_health_checker.cpp:71] Check 127.0.0.1:9996 healthy=0
# [2026-01-14 19:19:59.287] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EventLoop.cpp:72] EventLoop 0x7fffdbe63d50 stop looping
# [2026-01-14 19:19:59.287] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/unit/test_http_health_checker.cpp:83] HttpHealthChecker: PASS
# RUN test_ai_service_check
# $ /home/huazi/Workspace/Projects/linux大作业/build/test_ai_service_check
# RUN test_script_health_checker
# $ /home/huazi/Workspace/Projects/linux大作业/build/test_script_health_checker
# RUN test_warmup
# $ /home/huazi/Workspace/Projects/linux大作业/build/test_warmup
# RUN test_backend_manager
# $ /home/huazi/Workspace/Projects/linux大作业/build/test_backend_manager
# [2026-01-14 19:20:00.122] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/unit/test_backend_manager.cpp:15] === Testing BackendManager ===
# [2026-01-14 19:20:00.122] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EpollPoller.cpp:147] Using EpollPoller
# [2026-01-14 19:20:00.123] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EventLoop.cpp:61] EventLoop 0x7ffc0631cba0 start looping
# [2026-01-14 19:20:00.623] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/balancer/BackendManager.cpp:834] Backend 127.0.0.1:9991 health changed to DOWN
# [2026-01-14 19:20:02.123] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/unit/test_backend_manager.cpp:46] Test Phase 1 Check:
# [2026-01-14 19:20:02.123] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/unit/test_backend_manager.cpp:53] Nodes selected: 127.0.0.1:9990, 127.0.0.1:9990, 127.0.0.1:9990
# [2026-01-14 19:20:02.123] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/unit/test_backend_manager.cpp:56] BackendManager Health Logic: PASS
# [2026-01-14 19:20:02.123] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EventLoop.cpp:72] EventLoop 0x7ffc0631cba0 stop looping
# RUN test_backend_conn_pool
# $ /home/huazi/Workspace/Projects/linux大作业/build/test_backend_conn_pool
# [2026-01-14 19:20:02.155] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EpollPoller.cpp:147] Using EpollPoller
# [2026-01-14 19:20:02.155] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/ProxyServer.cpp:2765] Added backend: 127.0.0.1:33439 weight=1
# [2026-01-14 19:20:02.155] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/ProxyServer.cpp:2750] ProxyServer starts listening on 0.0.0.0:44387
# [2026-01-14 19:20:02.156] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EventLoop.cpp:61] EventLoop 0x7ffc5fcd6fb0 start looping
# [2026-01-14 19:20:02.356] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/TcpServer.cpp:195] TcpServer::NewConnection [PoolProxy] - new connection [PoolProxy-0.0.0.0:44387#1] from 127.0.0.1:47958
# [2026-01-14 19:20:02.357] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/common/MemoryPool.cpp:53] MemoryPool buddy enabled: min_kb=128 arena_kb=8192 keep_arenas=1 max_arenas=8
# [2026-01-14 19:20:02.357] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/ProxyServer.cpp:2782] New connection from 127.0.0.1:47958
# [2026-01-14 19:20:02.357] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/ProxyServer.cpp:4344] HTTP Request: GET /a
# [2026-01-14 19:20:02.357] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/TcpClient.cpp:26] TcpClient::TcpClient[PoolBackend] - connector 0x564827bfd940
# [2026-01-14 19:20:02.357] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/TcpClient.cpp:52] TcpClient::Connect[PoolBackend] - connecting to 127.0.0.1:33439
# [2026-01-14 19:20:02.357] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/ProxyServer.cpp:2791] Connection closed: PoolProxy-0.0.0.0:44387#1
# [2026-01-14 19:20:02.357] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/TcpServer.cpp:223] TcpServer::RemoveConnectionInLoop [PoolProxy] - connection PoolProxy-0.0.0.0:44387#1
# [2026-01-14 19:20:02.357] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/TcpServer.cpp:195] TcpServer::NewConnection [PoolProxy] - new connection [PoolProxy-0.0.0.0:44387#2] from 127.0.0.1:47964
# [2026-01-14 19:20:02.357] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/ProxyServer.cpp:2782] New connection from 127.0.0.1:47964
# [2026-01-14 19:20:02.357] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/ProxyServer.cpp:4344] HTTP Request: GET /b
# [2026-01-14 19:20:02.358] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EventLoop.cpp:72] EventLoop 0x7ffc5fcd6fb0 stop looping
# [2026-01-14 19:20:02.558] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/TcpClient.cpp:30] TcpClient::~TcpClient[PoolBackend] - connector 0x564827bfd940
# RUN test_model_affinity
# $ /home/huazi/Workspace/Projects/linux大作业/build/test_model_affinity
# PASS
# RUN test_service_discovery
# $ /home/huazi/Workspace/Projects/linux大作业/build/test_service_discovery
# RUN test_dynamic_register
# $ /home/huazi/Workspace/Projects/linux大作业/build/test_dynamic_register
# RUN test_passive_failover
# $ /home/huazi/Workspace/Projects/linux大作业/build/test_passive_failover
# [2026-01-14 19:20:02.824] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EpollPoller.cpp:147] Using EpollPoller
# [2026-01-14 19:20:02.824] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/balancer/BackendManager.cpp:613] Backend 127.0.0.1:9101 marked DOWN by passive failure signal
# [2026-01-14 19:20:02.824] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/unit/test_passive_failover.cpp:27] Passive failover: PASS
#
# --- SUMMARY ---
# OK
# ran: 16 skipped: 0 failed: 0

# %%
# Block C
results["C"] = run_module("C")
# Out:
# ============================================================
# MODULE C
# ============================================================
# RUN test_http
# $ /home/huazi/Workspace/Projects/linux大作业/build/test_http
# [2026-01-14 19:20:09.563] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/common/MemoryPool.cpp:53] MemoryPool buddy enabled: min_kb=128 arena_kb=8192 keep_arenas=1 max_arenas=8
# [2026-01-14 19:20:09.563] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/unit/test_http.cpp:41] Parse Request PASS
# [2026-01-14 19:20:09.563] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/unit/test_http.cpp:67] Parse Content-Length Body PASS
# [2026-01-14 19:20:09.563] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/unit/test_http.cpp:90] Parse Chunked Body PASS
# [2026-01-14 19:20:09.563] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/unit/test_http.cpp:114] Response Gen PASS
# RUN test_httpserver
# $ /home/huazi/Workspace/Projects/linux大作业/build/test_httpserver
# [2026-01-14 19:20:09.581] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EpollPoller.cpp:147] Using EpollPoller
# [2026-01-14 19:20:09.581] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/protocol/HttpServer.cpp:22] HttpServer[GeminiHttpServer] starts listening on 0.0.0.0:43455
# [2026-01-14 19:20:09.581] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EventLoop.cpp:61] EventLoop 0x7ffd5227ca10 start looping
# [2026-01-14 19:20:09.782] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/TcpServer.cpp:195] TcpServer::NewConnection [GeminiHttpServer] - new connection [GeminiHttpServer-0.0.0.0:43455#1] from 127.0.0.1:51260
# [2026-01-14 19:20:09.783] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/common/MemoryPool.cpp:53] MemoryPool buddy enabled: min_kb=128 arena_kb=8192 keep_arenas=1 max_arenas=8
# [2026-01-14 19:20:09.783] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/integration/test_httpserver.cpp:99] HttpServer - Request: /
# [2026-01-14 19:20:09.783] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/integration/test_httpserver.cpp:99] HttpServer - Request: /hello
# [2026-01-14 19:20:09.783] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/tests/integration/test_httpserver.cpp:99] HttpServer - Request: /quit
# [2026-01-14 19:20:09.783] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EventLoop.cpp:72] EventLoop 0x7ffd5227ca10 stop looping
# RUN test_http_keepalive_chunked
# $ /home/huazi/Workspace/Projects/linux大作业/build/test_http_keepalive_chunked
# [2026-01-14 19:20:09.804] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EpollPoller.cpp:147] Using EpollPoller
# [2026-01-14 19:20:09.805] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/protocol/HttpServer.cpp:22] HttpServer[HttpKeepAliveChunkedTest] starts listening on 0.0.0.0:9979
# [2026-01-14 19:20:09.805] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EventLoop.cpp:61] EventLoop 0x7ffeabc35090 start looping
# [2026-01-14 19:20:10.005] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/TcpServer.cpp:195] TcpServer::NewConnection [HttpKeepAliveChunkedTest] - new connection [HttpKeepAliveChunkedTest-0.0.0.0:9979#1] from 127.0.0.1:57588
# [2026-01-14 19:20:10.006] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/common/MemoryPool.cpp:53] MemoryPool buddy enabled: min_kb=128 arena_kb=8192 keep_arenas=1 max_arenas=8
# [2026-01-14 19:20:10.006] [INFO ] [/home/huazi/Workspace/Projects/linux大作业/src/network/EventLoop.cpp:72] EventLoop 0x7ffeabc35090 stop looping
# RUN test_http2_basic
# $ /home/huazi/Workspace/Projects/linux大作业/build/test_http2_basic

# %%
# Block D
results["D"] = run_module("D")
